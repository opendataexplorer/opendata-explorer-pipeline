# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import getsize, splitext
import requests
import math
from itertools import chain
import json

# %% [markdown]
# # Metadata Table

# %% [markdown]
# ## Statistics Canada

# %% [markdown]
# 1. Download Raw Metadata Table

# %%
statscan_raw_metadata_table = pd.read_json("https://www150.statcan.gc.ca/t1/wds/rest/getAllCubesList")

# %% [markdown]
# 2. Merge Subject Codes

# %%
def create_subject(x):
    """Matches Subject Code ID with Subject Code Label
    
    Parameters:
    x (pandas.Table): A grouped table

    Returns:
    pandas.Series: A Series with nested Subject Codes
    """
    d={}
    subject_object=[]
    for index, value in enumerate(x['subjectCode']):
        sub_obj = {'code': value, 'name': x['English'].tolist()[index]}
        subject_object.append(sub_obj)
    d['subject'] = subject_object
    return pd.Series(d, index=['subject'])

# %%
lookup_subject_codes = pd.read_csv("data/lookup/lookup-subject-codes.csv")

statscan_metadata_table = (statscan_raw_metadata_table
    .explode('subjectCode')
    .astype({'subjectCode':'int64'})
    .merge(lookup_subject_codes, how='left', left_on='subjectCode', right_on= 'Subject Code')
    .groupby('productId')
    .apply(create_subject)
    .reset_index()
    .merge(statscan_raw_metadata_table, how='inner', on='productId')
    .drop(columns=['subjectCode', 'corrections'])
    .drop_duplicates(subset='productId'))

# %%
statscan_metadata_table
# Out:
#       productId                               subject  cansimId  \
# 0      10100001  [{'code': 10, 'name': 'Government'}]  183-0021
# 1      10100002  [{'code': 10, 'name': 'Government'}]  191-0002
# 2      10100003  [{'code': 10, 'name': 'Government'}]  176-0079
# 3      10100004  [{'code': 10, 'name': 'Government'}]  176-0013
# 4      10100005  [{'code': 10, 'name': 'Government'}]  385-0041
# ...         ...                                   ...       ...
# 5994   46100053     [{'code': 46, 'name': 'Housing'}]      None
# 5995   46100054     [{'code': 46, 'name': 'Housing'}]      None
# 5996   46100055     [{'code': 46, 'name': 'Housing'}]      None
# 5997   46100056     [{'code': 46, 'name': 'Housing'}]      None
# 5998   46100057     [{'code': 46, 'name': 'Housing'}]      None
#
#                                             cubeTitleEn  \
# 0     Federal public sector employment reconciliatio...
# 1                               Central government debt
# 2     Government of Canada debt securities: Gross ne...
# 3     Chartered banks, total claims and liabilities ...
# 4     Canadian Classification of Functions of Govern...
# ...                                                 ...
# 5994  Ownership type and property use by residential...
# 5995  Residency ownership and property use by reside...
# 5996  Persons living with housing problems, by selec...
# 5997  Core housing need, by tenure including first-t...
# 5998  Number of residential properties sold and sale...
#
#                                             cubeTitleFr cubeStartDate  \
# 0     Emploi du secteur public fédéral rapprochement...    1999-01-01
# 1                         Dette du gouvernement central    2009-04-01
# 2     Titres d’emprunt du gouvernement du Canada : é...    1975-01-01
# 3     Banques à charte, ensembles des créances et en...    1978-04-01
# 4     Classification canadienne des fonctions des ad...    2008-01-01
# ...                                                 ...           ...
# 5994  Type de propriétaire et usage de la propriété ...    2018-01-01
# 5995  Résidence de la propriété et usage de la propr...    2018-01-01
# 5996  Personnes éprouvant des problèmes de logement,...    2018-01-01
# 5997  Besoins impérieux en matière de logement, selo...    2018-01-01
# 5998  Nombre de propriétés résidentielles vendues et...    2018-01-01
#
#      cubeEndDate       releaseTime  archived surveyCode  frequencyCode  \
# 0     2011-01-01  2012-08-01T12:30         1     [1713]             12
# 1     2021-10-01  2021-12-20T13:30         2     [7514]              6
# 2     2021-11-01  2021-12-22T13:30         2     [7502]              6
# 3     2021-07-01  2021-12-21T13:30         2     [7502]              9
# 4     2020-01-01  2021-11-26T13:30         2     [5218]             12
# ...          ...               ...       ...        ...            ...
# 5994  2020-01-01  2022-01-06T13:30         2     [5257]             12
# 5995  2020-01-01  2022-01-06T13:30         2     [5257]             12
# 5996  2018-01-01  2020-10-02T12:30         2     [5269]             13
# 5997  2018-01-01  2020-10-02T12:30         2     [5269]             13
# 5998  2018-01-01  2021-08-11T12:30         2     [5257]             12
#
#                                              dimensions
# 0     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 1     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 2     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 3     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 4     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# ...                                                 ...
# 5994  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5995  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5996  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5997  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5998  [{'dimensionNameEn': 'Geography', 'dimensionNa...
#
# [5999 rows x 12 columns]

# %% [markdown]
# ## City of Edmonton Metadata

# %% [markdown]
# 1. Configuration

# %%
edmonton_socrata_url = "http://api.us.socrata.com/api/catalog/v1?domains=data.edmonton.ca"
edmonton_socrata_request_length = requests.get(edmonton_socrata_url, params={"only":"datasets"}).json()["resultSetSize"]
edmonton_socrata_request_paginate = math.ceil(edmonton_socrata_request_length/100)

# %% [markdown]
# 2. Paginate through metadata return

# %%
edmonton_socrata_raw_request = []

for offset_counter in range(edmonton_socrata_request_paginate):
    edmonton_socrata_raw = requests.get(edmonton_socrata_url, params={"only":"datasets", "offset":offset_counter}).json()
    edmonton_socrata_raw_request.append(edmonton_socrata_raw["results"])

edmonton_socrata_raw_metadata = list(chain.from_iterable(edmonton_socrata_raw_request))

# %%
len(edmonton_socrata_raw_metadata)
# Out:
# 1300

# %%
with open("edmonton_socrata_raw_metadata.json", "w") as f:
    json.dump(edmonton_socrata_raw_metadata, f)
