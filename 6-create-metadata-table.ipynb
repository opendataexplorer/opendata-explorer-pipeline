# %%
import numpy as np
import pandas as pd
from os import listdir
from os.path import getsize, splitext

# %% [markdown]
# # Create Metadata Table
#
# ## Reference
#
# [User guide](https://www.statcan.gc.ca/en/developers/csv/user-guide): What fields in the returned CSV's means.
#
# [Web Data Service](https://www.statcan.gc.ca/en/developers/wds): How to interact with the Statscan API

# %% [markdown]
# ## Download

# %%
data_table = pd.read_json("https://www150.statcan.gc.ca/t1/wds/rest/getAllCubesList")

# %%
data_table
# Out:
#       productId  cansimId                                        cubeTitleEn  \
# 0      10100001  183-0021  Federal public sector employment reconciliatio...
# 1      10100002  191-0002                            Central government debt
# 2      10100003  176-0079  Government of Canada debt securities: Gross ne...
# 3      10100004  176-0013  Chartered banks, total claims and liabilities ...
# 4      10100005  385-0041  Canadian Classification of Functions of Govern...
# ...         ...       ...                                                ...
# 5982   46100053      None  Ownership type and property use by residential...
# 5983   46100054      None  Residency ownership and property use by reside...
# 5984   46100055      None  Persons living with housing problems, by selec...
# 5985   46100056      None  Core housing need, by tenure including first-t...
# 5986   46100057      None  Number of residential properties sold and sale...
#
#                                             cubeTitleFr cubeStartDate  \
# 0     Emploi du secteur public fédéral rapprochement...    1999-01-01
# 1                         Dette du gouvernement central    2009-04-01
# 2     Titres d’emprunt du gouvernement du Canada : é...    1975-01-01
# 3     Banques à charte, ensembles des créances et en...    1978-04-01
# 4     Classification canadienne des fonctions des ad...    2008-01-01
# ...                                                 ...           ...
# 5982  Type de propriétaire et usage de la propriété ...    2018-01-01
# 5983  Résidence de la propriété et usage de la propr...    2018-01-01
# 5984  Personnes éprouvant des problèmes de logement,...    2018-01-01
# 5985  Besoins impérieux en matière de logement, selo...    2018-01-01
# 5986  Nombre de propriétés résidentielles vendues et...    2018-01-01
#
#      cubeEndDate       releaseTime  archived subjectCode surveyCode  \
# 0     2011-01-01  2012-08-01T12:30         1        [10]     [1713]
# 1     2021-08-01  2021-11-01T12:30         2        [10]     [7514]
# 2     2021-10-01  2021-11-23T13:30         2        [10]     [7502]
# 3     2021-04-01  2021-09-22T12:30         2        [10]     [7502]
# 4     2020-01-01  2021-11-26T13:30         2        [10]     [5218]
# ...          ...               ...       ...         ...        ...
# 5982  2020-01-01  2021-09-17T12:30         2        [46]     [5257]
# 5983  2020-01-01  2021-09-17T12:30         2        [46]     [5257]
# 5984  2018-01-01  2020-10-02T12:30         2        [46]     [5269]
# 5985  2018-01-01  2020-10-02T12:30         2        [46]     [5269]
# 5986  2018-01-01  2021-08-11T12:30         2        [46]     [5257]
#
#       frequencyCode corrections  \
# 0                12          []
# 1                 6          []
# 2                 6          []
# 3                 9          []
# 4                12          []
# ...             ...         ...
# 5982             12          []
# 5983             12          []
# 5984             13          []
# 5985             13          []
# 5986             12          []
#
#                                              dimensions
# 0     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 1     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 2     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 3     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 4     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# ...                                                 ...
# 5982  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5983  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5984  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5985  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5986  [{'dimensionNameEn': 'Geography', 'dimensionNa...
#
# [5987 rows x 13 columns]

# %% [markdown]
# ## Merge Subject Codes

# %%
lookup_subject_codes = pd.read_csv("data/lookup/lookup-subject-codes.csv")
lookup_subject_codes
# Out:
#      Subject Code                                            English  \
# 0              10                                         Government
# 1              11              Income, pensions, spending and wealth
# 2              12                                International trade
# 3              13                                             Health
# 4              14                                             Labour
# ..            ...                                                ...
# 584        430504  Immigration and ethnocultural diversity/Immigr...
# 585        430506  Immigration and ethnocultural diversity/Immigr...
# 586        430507  Immigration and ethnocultural diversity/Immigr...
# 587        430508  Immigration and ethnocultural diversity/Immigr...
# 588        430599  Immigration and ethnocultural diversity/Immigr...
#
#                                                 French
# 0                                         Gouvernement
# 1               Revenu, pensions, dépenses et richesse
# 2                               Commerce international
# 3                                                Santé
# 4                                              Travail
# ..                                                 ...
# 584  Immigration et diversité ethnoculturelle/Immig...
# 585  Immigration et diversité ethnoculturelle/Immig...
# 586  Immigration et diversité ethnoculturelle/Immig...
# 587  Immigration et diversité ethnoculturelle/Immig...
# 588  Immigration et diversité ethnoculturelle/Immig...
#
# [589 rows x 3 columns]

# %%
data_table_explosion = data_table.explode('subjectCode')
data_table_explosion = data_table_explosion.astype({'subjectCode':'int64'})
data_table_explosion
# Out:
#       productId  cansimId                                        cubeTitleEn  \
# 0      10100001  183-0021  Federal public sector employment reconciliatio...
# 1      10100002  191-0002                            Central government debt
# 2      10100003  176-0079  Government of Canada debt securities: Gross ne...
# 3      10100004  176-0013  Chartered banks, total claims and liabilities ...
# 4      10100005  385-0041  Canadian Classification of Functions of Govern...
# ...         ...       ...                                                ...
# 5982   46100053      None  Ownership type and property use by residential...
# 5983   46100054      None  Residency ownership and property use by reside...
# 5984   46100055      None  Persons living with housing problems, by selec...
# 5985   46100056      None  Core housing need, by tenure including first-t...
# 5986   46100057      None  Number of residential properties sold and sale...
#
#                                             cubeTitleFr cubeStartDate  \
# 0     Emploi du secteur public fédéral rapprochement...    1999-01-01
# 1                         Dette du gouvernement central    2009-04-01
# 2     Titres d’emprunt du gouvernement du Canada : é...    1975-01-01
# 3     Banques à charte, ensembles des créances et en...    1978-04-01
# 4     Classification canadienne des fonctions des ad...    2008-01-01
# ...                                                 ...           ...
# 5982  Type de propriétaire et usage de la propriété ...    2018-01-01
# 5983  Résidence de la propriété et usage de la propr...    2018-01-01
# 5984  Personnes éprouvant des problèmes de logement,...    2018-01-01
# 5985  Besoins impérieux en matière de logement, selo...    2018-01-01
# 5986  Nombre de propriétés résidentielles vendues et...    2018-01-01
#
#      cubeEndDate       releaseTime  archived  subjectCode surveyCode  \
# 0     2011-01-01  2012-08-01T12:30         1           10     [1713]
# 1     2021-08-01  2021-11-01T12:30         2           10     [7514]
# 2     2021-10-01  2021-11-23T13:30         2           10     [7502]
# 3     2021-04-01  2021-09-22T12:30         2           10     [7502]
# 4     2020-01-01  2021-11-26T13:30         2           10     [5218]
# ...          ...               ...       ...          ...        ...
# 5982  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5983  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5984  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 5985  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 5986  2018-01-01  2021-08-11T12:30         2           46     [5257]
#
#       frequencyCode corrections  \
# 0                12          []
# 1                 6          []
# 2                 6          []
# 3                 9          []
# 4                12          []
# ...             ...         ...
# 5982             12          []
# 5983             12          []
# 5984             13          []
# 5985             13          []
# 5986             12          []
#
#                                              dimensions
# 0     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 1     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 2     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 3     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 4     [{'dimensionNameEn': 'Geography', 'dimensionNa...
# ...                                                 ...
# 5982  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5983  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5984  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5985  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5986  [{'dimensionNameEn': 'Geography', 'dimensionNa...
#
# [6001 rows x 13 columns]

# %%
data_table_explosion.dtypes
# Out:
# productId         int64
# cansimId         object
# cubeTitleEn      object
# cubeTitleFr      object
# cubeStartDate    object
# cubeEndDate      object
# releaseTime      object
# archived          int64
# subjectCode       int64
# surveyCode       object
# frequencyCode     int64
# corrections      object
# dimensions       object
# dtype: object

# %%
data_table_explosion.productId.nunique()
# Out:
# 5987

# %%
data_table_merged = data_table_explosion.merge(lookup_subject_codes, how='left', left_on='subjectCode', right_on= 'Subject Code')
data_table_merged
# Out:
#       productId  cansimId                                        cubeTitleEn  \
# 0      10100001  183-0021  Federal public sector employment reconciliatio...
# 1      10100002  191-0002                            Central government debt
# 2      10100003  176-0079  Government of Canada debt securities: Gross ne...
# 3      10100004  176-0013  Chartered banks, total claims and liabilities ...
# 4      10100005  385-0041  Canadian Classification of Functions of Govern...
# ...         ...       ...                                                ...
# 5996   46100053      None  Ownership type and property use by residential...
# 5997   46100054      None  Residency ownership and property use by reside...
# 5998   46100055      None  Persons living with housing problems, by selec...
# 5999   46100056      None  Core housing need, by tenure including first-t...
# 6000   46100057      None  Number of residential properties sold and sale...
#
#                                             cubeTitleFr cubeStartDate  \
# 0     Emploi du secteur public fédéral rapprochement...    1999-01-01
# 1                         Dette du gouvernement central    2009-04-01
# 2     Titres d’emprunt du gouvernement du Canada : é...    1975-01-01
# 3     Banques à charte, ensembles des créances et en...    1978-04-01
# 4     Classification canadienne des fonctions des ad...    2008-01-01
# ...                                                 ...           ...
# 5996  Type de propriétaire et usage de la propriété ...    2018-01-01
# 5997  Résidence de la propriété et usage de la propr...    2018-01-01
# 5998  Personnes éprouvant des problèmes de logement,...    2018-01-01
# 5999  Besoins impérieux en matière de logement, selo...    2018-01-01
# 6000  Nombre de propriétés résidentielles vendues et...    2018-01-01
#
#      cubeEndDate       releaseTime  archived  subjectCode surveyCode  \
# 0     2011-01-01  2012-08-01T12:30         1           10     [1713]
# 1     2021-08-01  2021-11-01T12:30         2           10     [7514]
# 2     2021-10-01  2021-11-23T13:30         2           10     [7502]
# 3     2021-04-01  2021-09-22T12:30         2           10     [7502]
# 4     2020-01-01  2021-11-26T13:30         2           10     [5218]
# ...          ...               ...       ...          ...        ...
# 5996  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5997  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5998  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 5999  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 6000  2018-01-01  2021-08-11T12:30         2           46     [5257]
#
#       frequencyCode corrections  \
# 0                12          []
# 1                 6          []
# 2                 6          []
# 3                 9          []
# 4                12          []
# ...             ...         ...
# 5996             12          []
# 5997             12          []
# 5998             13          []
# 5999             13          []
# 6000             12          []
#
#                                              dimensions  Subject Code  \
# 0     [{'dimensionNameEn': 'Geography', 'dimensionNa...            10
# 1     [{'dimensionNameEn': 'Geography', 'dimensionNa...            10
# 2     [{'dimensionNameEn': 'Geography', 'dimensionNa...            10
# 3     [{'dimensionNameEn': 'Geography', 'dimensionNa...            10
# 4     [{'dimensionNameEn': 'Geography', 'dimensionNa...            10
# ...                                                 ...           ...
# 5996  [{'dimensionNameEn': 'Geography', 'dimensionNa...            46
# 5997  [{'dimensionNameEn': 'Geography', 'dimensionNa...            46
# 5998  [{'dimensionNameEn': 'Geography', 'dimensionNa...            46
# 5999  [{'dimensionNameEn': 'Geography', 'dimensionNa...            46
# 6000  [{'dimensionNameEn': 'Geography', 'dimensionNa...            46
#
#          English        French
# 0     Government  Gouvernement
# 1     Government  Gouvernement
# 2     Government  Gouvernement
# 3     Government  Gouvernement
# 4     Government  Gouvernement
# ...          ...           ...
# 5996     Housing      Logement
# 5997     Housing      Logement
# 5998     Housing      Logement
# 5999     Housing      Logement
# 6000     Housing      Logement
#
# [6001 rows x 16 columns]

# %%
def create_subject(x):
    d={}
    subject_object=[]
    for index, value in enumerate(x['subjectCode']):
        sub_obj = {'code': value, 'name': x['English'].tolist()[index]}
        subject_object.append(sub_obj)
    d['subject'] = subject_object
    return pd.Series(d, index=['subject'])


    
data_table_group = data_table_merged.groupby('productId').apply(create_subject)
data_table_group = data_table_group.reset_index()
data_table_group
# Out:
#       productId                               subject
# 0      10100001  [{'code': 10, 'name': 'Government'}]
# 1      10100002  [{'code': 10, 'name': 'Government'}]
# 2      10100003  [{'code': 10, 'name': 'Government'}]
# 3      10100004  [{'code': 10, 'name': 'Government'}]
# 4      10100005  [{'code': 10, 'name': 'Government'}]
# ...         ...                                   ...
# 5982   46100053     [{'code': 46, 'name': 'Housing'}]
# 5983   46100054     [{'code': 46, 'name': 'Housing'}]
# 5984   46100055     [{'code': 46, 'name': 'Housing'}]
# 5985   46100056     [{'code': 46, 'name': 'Housing'}]
# 5986   46100057     [{'code': 46, 'name': 'Housing'}]
#
# [5987 rows x 2 columns]

# %%
data_table_mergeback = data_table_group.merge(data_table_merged, how='inner', on='productId')
data_table_mergeback = data_table_mergeback.drop(columns=['Subject Code','English','French', 'corrections'])
data_table_mergeback = data_table_mergeback.drop_duplicates(subset='productId')
data_table_mergeback
# Out:
#       productId                               subject  cansimId  \
# 0      10100001  [{'code': 10, 'name': 'Government'}]  183-0021
# 1      10100002  [{'code': 10, 'name': 'Government'}]  191-0002
# 2      10100003  [{'code': 10, 'name': 'Government'}]  176-0079
# 3      10100004  [{'code': 10, 'name': 'Government'}]  176-0013
# 4      10100005  [{'code': 10, 'name': 'Government'}]  385-0041
# ...         ...                                   ...       ...
# 5996   46100053     [{'code': 46, 'name': 'Housing'}]      None
# 5997   46100054     [{'code': 46, 'name': 'Housing'}]      None
# 5998   46100055     [{'code': 46, 'name': 'Housing'}]      None
# 5999   46100056     [{'code': 46, 'name': 'Housing'}]      None
# 6000   46100057     [{'code': 46, 'name': 'Housing'}]      None
#
#                                             cubeTitleEn  \
# 0     Federal public sector employment reconciliatio...
# 1                               Central government debt
# 2     Government of Canada debt securities: Gross ne...
# 3     Chartered banks, total claims and liabilities ...
# 4     Canadian Classification of Functions of Govern...
# ...                                                 ...
# 5996  Ownership type and property use by residential...
# 5997  Residency ownership and property use by reside...
# 5998  Persons living with housing problems, by selec...
# 5999  Core housing need, by tenure including first-t...
# 6000  Number of residential properties sold and sale...
#
#                                             cubeTitleFr cubeStartDate  \
# 0     Emploi du secteur public fédéral rapprochement...    1999-01-01
# 1                         Dette du gouvernement central    2009-04-01
# 2     Titres d’emprunt du gouvernement du Canada : é...    1975-01-01
# 3     Banques à charte, ensembles des créances et en...    1978-04-01
# 4     Classification canadienne des fonctions des ad...    2008-01-01
# ...                                                 ...           ...
# 5996  Type de propriétaire et usage de la propriété ...    2018-01-01
# 5997  Résidence de la propriété et usage de la propr...    2018-01-01
# 5998  Personnes éprouvant des problèmes de logement,...    2018-01-01
# 5999  Besoins impérieux en matière de logement, selo...    2018-01-01
# 6000  Nombre de propriétés résidentielles vendues et...    2018-01-01
#
#      cubeEndDate       releaseTime  archived  subjectCode surveyCode  \
# 0     2011-01-01  2012-08-01T12:30         1           10     [1713]
# 1     2021-08-01  2021-11-01T12:30         2           10     [7514]
# 2     2021-10-01  2021-11-23T13:30         2           10     [7502]
# 3     2021-04-01  2021-09-22T12:30         2           10     [7502]
# 4     2020-01-01  2021-11-26T13:30         2           10     [5218]
# ...          ...               ...       ...          ...        ...
# 5996  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5997  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5998  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 5999  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 6000  2018-01-01  2021-08-11T12:30         2           46     [5257]
#
#       frequencyCode                                         dimensions
# 0                12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 1                 6  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 2                 6  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 3                 9  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 4                12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# ...             ...                                                ...
# 5996             12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5997             12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5998             13  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5999             13  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 6000             12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
#
# [5987 rows x 13 columns]

# %% [markdown]
# ## Merge Available Files

# %%
output_path = 'data/output'
files = listdir(output_path)
sizes = []
files_under_5mb = []
files_under_5mb_size = []
for file in files:
    sizes.append(getsize(f"{output_path}/{file}"))
    if getsize(f"{output_path}/{file}") < 5000000:
        files_under_5mb.append(file)
        files_under_5mb_size.append(getsize(f"{output_path}/{file}"))

# %%
only_datasets = []
for file in files_under_5mb:
    if "filters" not in file:
        only_datasets.append(int(splitext(file)[0]))
print(len(only_datasets))
# Out:
# 4032

# %%
dataset_frame = pd.DataFrame(only_datasets, columns=['productId'])
merge_available = data_table_mergeback.merge(dataset_frame, how='left', on='productId', indicator=True)
merge_available['available'] = np.where(merge_available['_merge'] == 'both', True, False)
merge_available
# Out:
#       productId                               subject  cansimId  \
# 0      10100001  [{'code': 10, 'name': 'Government'}]  183-0021
# 1      10100002  [{'code': 10, 'name': 'Government'}]  191-0002
# 2      10100003  [{'code': 10, 'name': 'Government'}]  176-0079
# 3      10100004  [{'code': 10, 'name': 'Government'}]  176-0013
# 4      10100005  [{'code': 10, 'name': 'Government'}]  385-0041
# ...         ...                                   ...       ...
# 5982   46100053     [{'code': 46, 'name': 'Housing'}]      None
# 5983   46100054     [{'code': 46, 'name': 'Housing'}]      None
# 5984   46100055     [{'code': 46, 'name': 'Housing'}]      None
# 5985   46100056     [{'code': 46, 'name': 'Housing'}]      None
# 5986   46100057     [{'code': 46, 'name': 'Housing'}]      None
#
#                                             cubeTitleEn  \
# 0     Federal public sector employment reconciliatio...
# 1                               Central government debt
# 2     Government of Canada debt securities: Gross ne...
# 3     Chartered banks, total claims and liabilities ...
# 4     Canadian Classification of Functions of Govern...
# ...                                                 ...
# 5982  Ownership type and property use by residential...
# 5983  Residency ownership and property use by reside...
# 5984  Persons living with housing problems, by selec...
# 5985  Core housing need, by tenure including first-t...
# 5986  Number of residential properties sold and sale...
#
#                                             cubeTitleFr cubeStartDate  \
# 0     Emploi du secteur public fédéral rapprochement...    1999-01-01
# 1                         Dette du gouvernement central    2009-04-01
# 2     Titres d’emprunt du gouvernement du Canada : é...    1975-01-01
# 3     Banques à charte, ensembles des créances et en...    1978-04-01
# 4     Classification canadienne des fonctions des ad...    2008-01-01
# ...                                                 ...           ...
# 5982  Type de propriétaire et usage de la propriété ...    2018-01-01
# 5983  Résidence de la propriété et usage de la propr...    2018-01-01
# 5984  Personnes éprouvant des problèmes de logement,...    2018-01-01
# 5985  Besoins impérieux en matière de logement, selo...    2018-01-01
# 5986  Nombre de propriétés résidentielles vendues et...    2018-01-01
#
#      cubeEndDate       releaseTime  archived  subjectCode surveyCode  \
# 0     2011-01-01  2012-08-01T12:30         1           10     [1713]
# 1     2021-08-01  2021-11-01T12:30         2           10     [7514]
# 2     2021-10-01  2021-11-23T13:30         2           10     [7502]
# 3     2021-04-01  2021-09-22T12:30         2           10     [7502]
# 4     2020-01-01  2021-11-26T13:30         2           10     [5218]
# ...          ...               ...       ...          ...        ...
# 5982  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5983  2020-01-01  2021-09-17T12:30         2           46     [5257]
# 5984  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 5985  2018-01-01  2020-10-02T12:30         2           46     [5269]
# 5986  2018-01-01  2021-08-11T12:30         2           46     [5257]
#
#       frequencyCode                                         dimensions  \
# 0                12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 1                 6  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 2                 6  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 3                 9  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 4                12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# ...             ...                                                ...
# 5982             12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5983             12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5984             13  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5985             13  [{'dimensionNameEn': 'Geography', 'dimensionNa...
# 5986             12  [{'dimensionNameEn': 'Geography', 'dimensionNa...
#
#          _merge  available
# 0          both       True
# 1          both       True
# 2     left_only      False
# 3     left_only      False
# 4          both       True
# ...         ...        ...
# 5982  left_only      False
# 5983  left_only      False
# 5984  left_only      False
# 5985  left_only      False
# 5986  left_only      False
#
# [5987 rows x 15 columns]

# %% [markdown]
# ## Output Final Metadata Table

# %%
merge_available.to_json("data/metadata/metadata.json", orient='records')

# %% [markdown]
# # Create Dimensions List

# %%
all_dimensions_list = []

for dimension_list in merge_available['dimensions']:
    for dimension in dimension_list:
        all_dimensions_list.append(dimension['dimensionNameEn'])
        

unique_set = set(all_dimensions_list)

print(len(unique_set))
# Out:
# 2893

# %%
dimensions = pd.DataFrame(unique_set, columns=['name'])

# %%
dimensions.to_json("data/metadata/dimensions.json", orient='records')
